# %% [raw]
# ---
# description: test what nbdev can do
# output-file: core.html
# title: test
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(denoise)
# Out:
# ---
#
# ### denoise
#
# >      denoise (a=1, b=2)

# %%
#| echo: false
#| output: asis
show_doc(motion_correction)
# Out:
# ---
#
# ### motion_correction
#
# >      motion_correction (to)
#
# say hello to somebody

# %%
motion_correction("Issac")
# Out:
# 'Hello Issac!'

# %%
assert denoise(3,4) == 7

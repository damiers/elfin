# %% [raw]
# ---
# description: test what nbdev can do
# output-file: test.html
# title: test
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(sum)
# Out:
# ---
#
# [source](https://github.com/DAMI-research/elfin/blob/main/elfin/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### sum
#
# >      sum (a=1, b=2)

# %%
#| echo: false
#| output: asis
show_doc(say_hello)
# Out:
# ---
#
# [source](https://github.com/DAMI-research/elfin/blob/main/elfin/core.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### say_hello
#
# >      say_hello (to)
#
# say hello to somebody

# %%
say_hello("Issac")
# Out:
# 'Hello Issac!'

# %%
assert sum(3,4) == 7

# %%
from IPython.display import display, SVG

# %%
display(SVG('<svg height="100" xmlns="http://www.w3.org/2000/svg"><circle cx="50" cy="50" r="40"/></svg>'))
